# %% [markdown]
# 1. Extract data preprocessing and model training code into src/preprocess.py and src/model.py:
#    * preprocess() in preprocess.py
#    * train_model(), evaluate_model() in model.py
# 2. Write two or three unit tests using pytest in src/tests/:
#    * Test that preprocess outputs correct column count and no NaN for DataFrame with missing and outlier values
#    * Test that model output label range is valid (0/1) on small mock data
# 3. Run !pytest src/tests in the Notebook to show test results

# %%
import subprocess
import sys

# %%
# ── 1. Verify file structure ────────────────────────────────────────
import os
for path in ['../src/preprocess.py', '../src/model.py',
             '../src/tests/test_preprocess.py', '../src/tests/test_model.py']:
    status = '[PASS]' if os.path.exists(path) else '[FAIL]'
    print(f"{status} {path}")
# Out:
# [PASS] ../src/preprocess.py
# [PASS] ../src/model.py
# [PASS] ../src/tests/test_preprocess.py
# [PASS] ../src/tests/test_model.py

# %%
# ── 2. Run pytest ─────────────────────────────────────────
result = subprocess.run(
    [sys.executable, '-m', 'pytest', '../src/tests', '-v', '--tb=short'],
    capture_output=True, text=True
)
print(result.stdout)
if result.returncode != 0:
    print(result.stderr)
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.1, pytest-9.0.2, pluggy-1.6.0 -- d:\AI_testing_HandsOn\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: d:\AI_testing_HandsOn\working
# collecting ... collected 3 items
#
# ..\src\tests\test_model.py::test_predict_labels_valid PASSED             [ 33%]
# ..\src\tests\test_model.py::test_cv_scores_range PASSED                  [ 66%]
# ..\src\tests\test_model.py::test_evaluate_model_accuracy PASSED          [100%]
#
# ============================== 3 passed in 2.55s ==============================
